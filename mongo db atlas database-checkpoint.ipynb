# %% [markdown]
# ## install pymongo library

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dnspython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo

# %% [markdown]
# ## to obtain mongo db client reference

# %%
client = pymongo.MongoClient("mongodb+srv://preeti7006:compassdspmdb67@cluster0.rvu1f.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test

# %% [markdown]
# ## to create a database

# %%
database_name = "student"
student_database = client[database_name]

# %% [markdown]
# ## to create collection

# %%
collection = 'student_detail'

# %%
student_detail_collection = student_database[collection]

# %% [markdown]
# ## to create document inside collection

# %%
student_data = {
    "name":"Preeti",
    "college":"LBC",
    "address":"earth planet"
}

# %%
student_detail_collection.insert_one(student_data)

# %% [markdown]
# ## to fetch details from mongo db atlas

# %%
student_cursor = student_detail_collection.find()

# %%
student_cursor.next()
# Out:
# {'_id': ObjectId('6188b55d09fe5aaa023cca64'),
#  'name': 'Preeti',
#  'college': 'LBC',
#  'address': 'earth planet'}

# %%
for student_detail in student_detail_collection.find():
    print(student_detail)
# Out:
# {'_id': ObjectId('6188b55d09fe5aaa023cca64'), 'name': 'Preeti', 'college': 'LBC', 'address': 'earth planet'}
# {'_id': ObjectId('6188b5d2ab75d00cbd51b142'), 'name': 'Preeti', 'college': 'LBC', 'address': 'earth planet'}
# {'_id': ObjectId('6188b6d0d87dc3ad6cafe225'), 'name': 'Preeti', 'college': 'LBC', 'address': 'earth planet'}
# {'_id': ObjectId('6188bb13d87dc3ad6cafe226'), 'name': 'Preeti', 'college': 'LBC', 'address': 'earth planet'}

# %% [markdown]
# ## to insert multiple record in database

# %%
student_data_list = [
    {"name":"satadeepa","last_name":"das","designation":"student"},
    {"city":"kolkata","college":"thk",},
    {"relation":"bestie","address":"earth","hobby":"reading"},
]

# %%
student_detail_collection.insert_many(student_data_list)

# %%
for student_detail in student_detail_collection.find():
    print(student_detail)
# Out:
# {'_id': ObjectId('6188b55d09fe5aaa023cca64'), 'name': 'Preeti', 'college': 'LBC', 'address': 'earth planet'}
# {'_id': ObjectId('6188b5d2ab75d00cbd51b142'), 'name': 'Preeti', 'college': 'LBC', 'address': 'earth planet'}
# {'_id': ObjectId('6188b6d0d87dc3ad6cafe225'), 'name': 'Preeti', 'college': 'LBC', 'address': 'earth planet'}
# {'_id': ObjectId('6188bb13d87dc3ad6cafe226'), 'name': 'Preeti', 'college': 'LBC', 'address': 'earth planet'}
# {'_id': ObjectId('6188be8ad87dc3ad6cafe227'), 'name': 'satadeepa', 'last_name': 'das', 'designation': 'student'}
# {'_id': ObjectId('6188be8ad87dc3ad6cafe228'), 'city': 'kolkata', 'college': 'thk'}
# {'_id': ObjectId('6188be8ad87dc3ad6cafe229'), 'relation': 'bestie', 'address': 'earth', 'hobby': 'reading'}

# %% [markdown]
# ## to apply filter

# %%
query = {"name":"satadeepa"}

# %%
for student_detail in student_detail_collection.find(query):
    print(student_detail)
# Out:
# {'_id': ObjectId('6188be8ad87dc3ad6cafe227'), 'name': 'satadeepa', 'last_name': 'das', 'designation': 'student'}
